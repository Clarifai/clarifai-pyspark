# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/mansikhamkar/work/clarifai_work/github_repos/clarifai-pyspark
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: clarifai==9.9.3 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifaipyspark==0.1) (9.9.3)
# Requirement already satisfied: pyspark==3.5.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifaipyspark==0.1) (3.5.0)
# Requirement already satisfied: clarifai-grpc==9.8.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (9.8.1)
# Requirement already satisfied: pandas==1.3.5 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (1.3.5)
# Requirement already satisfied: numpy==1.22.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (1.22.0)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (4.65.0)
# Requirement already satisfied: omegaconf==2.2.3 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (2.2.3)
# Requirement already satisfied: pycocotools==2.0.6 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (2.0.6)
# Requirement already satisfied: opencv-python==4.7.0.68 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (4.7.0.68)
# Requirement already satisfied: tritonclient==2.34.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (2.34.0)
# Requirement already satisfied: rich==13.4.2 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (13.4.2)
# Requirement already satisfied: pytest==7.4.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (7.4.1)
# Requirement already satisfied: PyYAML==6.0.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (6.0.1)
# Requirement already satisfied: schema==0.7.5 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai==9.9.3->clarifaipyspark==0.1) (0.7.5)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pyspark==3.5.0->clarifaipyspark==0.1) (0.10.9.7)
# Requirement already satisfied: grpcio>=1.44.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (1.56.2)
# Requirement already satisfied: protobuf>=3.20.3 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (4.24.4)
# Requirement already satisfied: googleapis-common-protos>=1.53.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (1.55.0)
# Requirement already satisfied: requests>=2.25.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (2.31.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from omegaconf==2.2.3->clarifai==9.9.3->clarifaipyspark==0.1) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pandas==1.3.5->clarifai==9.9.3->clarifaipyspark==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pandas==1.3.5->clarifai==9.9.3->clarifaipyspark==0.1) (2023.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pycocotools==2.0.6->clarifai==9.9.3->clarifaipyspark==0.1) (3.5.3)
# Requirement already satisfied: iniconfig in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pytest==7.4.1->clarifai==9.9.3->clarifaipyspark==0.1) (2.0.0)
# Requirement already satisfied: packaging in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pytest==7.4.1->clarifai==9.9.3->clarifaipyspark==0.1) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pytest==7.4.1->clarifai==9.9.3->clarifaipyspark==0.1) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pytest==7.4.1->clarifai==9.9.3->clarifaipyspark==0.1) (1.1.2)
# Requirement already satisfied: tomli>=1.0.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from pytest==7.4.1->clarifai==9.9.3->clarifaipyspark==0.1) (2.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from rich==13.4.2->clarifai==9.9.3->clarifaipyspark==0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from rich==13.4.2->clarifai==9.9.3->clarifaipyspark==0.1) (2.15.1)
# Requirement already satisfied: contextlib2>=0.5.5 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from schema==0.7.5->clarifai==9.9.3->clarifaipyspark==0.1) (21.6.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from tritonclient==2.34.0->clarifai==9.9.3->clarifaipyspark==0.1) (1.10)
# Requirement already satisfied: mdurl~=0.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich==13.4.2->clarifai==9.9.3->clarifaipyspark==0.1) (0.1.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6->clarifai==9.9.3->clarifaipyspark==0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6->clarifai==9.9.3->clarifaipyspark==0.1) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6->clarifai==9.9.3->clarifaipyspark==0.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6->clarifai==9.9.3->clarifaipyspark==0.1) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools==2.0.6->clarifai==9.9.3->clarifaipyspark==0.1) (3.1.0)
# Requirement already satisfied: six>=1.5 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas==1.3.5->clarifai==9.9.3->clarifaipyspark==0.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from requests>=2.25.1->clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from requests>=2.25.1->clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from requests>=2.25.1->clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mansikhamkar/virtualenv/v1/lib/python3.9/site-packages (from requests>=2.25.1->clarifai-grpc==9.8.1->clarifai==9.9.3->clarifaipyspark==0.1) (2023.7.22)
# Installing collected packages: clarifaipyspark
#   Attempting uninstall: clarifaipyspark
#     Found existing installation: clarifaipyspark 0.1
#     Uninstalling clarifaipyspark-0.1:
#       Successfully uninstalled clarifaipyspark-0.1
#   Running setup.py develop for clarifaipyspark
# Successfully installed clarifaipyspark-0.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip

# %%
from clarifaipyspark.client import ClarifaiPySpark
from clarifaipyspark.dataset import Dataset

import os

os.environ['CLARIFAI_PAT'] = '95978ef1e65e4e1ab8b268e94a49b1e9'

# %%
cspark_obj = ClarifaiPySpark(user_id='mansi_k', app_id='databricks_tester')

dataset_obj = cspark_obj.dataset(dataset_id='dataset1')

# %%
my_inputs = dataset_obj.list_inputs_from_dataset()

my_inputs
# Out:
# [id: "1720"
#  data {
#    image {
#      url: "https://db-test-bucket-integration.s3.amazonaws.com/images-test/portal-onboarding5.jpg"
#      hosted {
#        prefix: "https://data.clarifai.com"
#        suffix: "users/mansi_k/apps/databricks_tester/inputs/image/ab83bb83761d14f99e99e52b537b699d"
#        sizes: "orig"
#        sizes: "tiny"
#        sizes: "small"
#        sizes: "large"
#        crossorigin: "use-credentials"
#      }
#      image_info {
#        width: 1000
#        height: 750
#        format: "JPEG"
#        color_mode: "YUV"
#      }
#    }
#  }
#  created_at {
#    seconds: 1697020382
#    nanos: 703977000
#  }
#  modified_at {
#    seconds: 1697020383
#    nanos: 389180000
#  }
#  status {
#    code: INPUT_DOWNLOAD_SUCCESS
#    description: "Download complete"
#  },
#  id: "1504"
#  data {
#    image {
#      url: "https://db-test-bucket-integration.s3.amazonaws.com/images-test/portal-onboarding4.jpg"
#      hosted {
#        prefix: "https://data.clarifai.com"
#        suffix: "users/mansi_k/apps/databricks_tester/inputs/image/fda290b2d99ea81d1728db0d5c002797"
#        sizes: "orig"
#        sizes: "tiny"
#        sizes: "small"
#        sizes: "large"
#        crossorigin: "use-credentials"
#      }
#      image_info {
#        width: 694
#        height: 1000
#        format: "JPEG"
#        color_mode: "YUV"
#      }
#    }
#  }
#  created_at {
#    seconds: 1697020382
#    nanos: 602753000
#  }
#  modified_at {
#    seconds: 1697020383
#    nanos: 363409000
#  }
#  status {
#    code: INPUT_DOWNLOAD_SUCCESS
#    description: "Download complete"
#  },
#  id: "1597"
#  data {
#    image {
#      url: "https://db-test-bucket-integration.s3.amazonaws.com/images-test/portal-onboarding2.jpg"
#      hosted {
#        prefix: "https://data.clarifai.com"
#        suffix: "users/mansi_k/apps/databricks_tester/inputs/image/50b006351b633ec2677bef18b7278f3b"
#        sizes: "orig"
#        sizes: "tiny"
#        sizes: "small"
#        sizes: "large"
#        crossorigin: "use-credentials"
#      }
#      image_info {
#        width: 1000
#        height: 663
#        format: "JPEG"
#        color_mode: "YUV"
#      }
#    }
#  }
#  created_at {
#    seconds: 1697020382
#    nanos: 501628000
#  }
#  modified_at {
#    seconds: 1697020383
#    nanos: 134192000
#  }
#  status {
#    code: INPUT_DOWNLOAD_SUCCESS
#    description: "Download complete"
#  },
#  id: "5020"
#  data {
#    image {
#      url: "https://db-test-bucket-integration.s3.amazonaws.com/images-test/portal-onboarding11.jpg"
#      hosted {
#        prefix: "https://data.clarifai.com"
#        suffix: "users/mansi_k/apps/databricks_tester/inputs/image/fad352f146f0381d9a303de6720d5c42"
#        sizes: "orig"
#        sizes: "tiny"
#        sizes: "small"
#        sizes: "large"
#        crossorigin: "use-credentials"
#      }
#      image_info {
#        width: 1000
#        height: 666
#        format: "JPEG"
#        color_mode: "YUV"
#      }
#    }
#  }
#  created_at {
#    seconds: 1697020382
#    nanos: 404988000
#  }
#  modified_at {
#    seconds: 1697020383
#    nanos: 29516000
#  }
#  status {
#    code: INPUT_DOWNLOAD_SUCCESS
#    description: "Download complete"
#  },
#  id: "1102"
#  data {
#    image {
#      url: "https://db-test-bucket-integration.s3.amazonaws.com/images-test/portal-onboarding10.jpg"
#      hosted {
#        prefix: "https://data.clarifai.com"
#        suffix: "users/mansi_k/apps/databricks_tester/inputs/image/a81598f16d3cbf68760d8580d81cfd8c"
#        sizes: "orig"
#        sizes: "tiny"
#        sizes: "small"
#        sizes: "large"
#        crossorigin: "use-credentials"
#      }
#      image_info {
#        width: 666
#        height: 1000
#        format: "JPEG"
#        color_mode: "YUV"
#      }
#    }
#  }
#  created_at {
#    seconds: 1697020382
#    nanos: 293298000
#  }
#  modified_at {
#    seconds: 1697020383
#    nanos: 76677000
#  }
#  status {
#    code: INPUT_DOWNLOAD_SUCCESS
#    description: "Download complete"
#  }]
